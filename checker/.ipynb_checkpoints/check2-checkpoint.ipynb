# %%
import numpy as np
import chainer
from chainer import cuda, Function, gradient_check, report, training, utils, Variable
from chainer import datasets, iterators, optimizers, serializers
from chainer import Link, Chain, ChainList
import chainer.functions as F
import chainer.links as L
from chainer.training import extensions
from matplotlib import pyplot as plt
# %matplotlib inline 
xp = cuda.cupy
import time


def model_func(model):
    if xp == np:
        pass
    else :
        gpu_device = 0
        cuda.get_device(gpu_device).use()
        model.to_gpu(gpu_device)
xp.model_init = model_func
xp.pi = np.pi

# %%
def mk_seq_dat(N=5000,t = False,k=5):
    x = xp.random.randn(N,2,dtype=np.float32) * 2
    if t == True:
        x = xp.random.uniform(-k,k,(N,2)).astype(np.float32)
    t = xp.where(x[:,0] % 2 > 1,0,1)
    t+= xp.where(x[:,1] % 2 > 1,0,1)
    t %= 2
    t = t.astype(np.int32)
    return (x,t)
(dx,dt) = mk_seq_dat(5000,False)

cx = cuda.to_cpu(dx)
ct = cuda.to_cpu(dt)
plt.scatter(cx[:,0][ct==0],cx[:,1][ct==0])
plt.scatter(cx[:,0][ct==1],cx[:,1][ct==1])

# %%
def getMini(dx,dt,mN = 50):
    r = np.random.randint(dx.shape[0]//mN)
    return ( dx[r*mN:(r+1)*mN] , dt[r*mN:(r+1)*mN] )

# %%
class Path:
    def __init__(this,val):
        this.v = val
        
    def __call__(this,func = None):
        if func == None :
            return this.v
        else:
            return Path(func(this.v))
    def __str__(this):
        return "$"+str(this.v)
    
def add1(v):
    return v+1

def mul2(v):
    return v*2

a = Path(1)(add1)(add1)(mul2)(add1)(mul2)(add1)()
print (a)
# Out:
# 15

# %%
def prt_shape(v):
    print (v.shape)
    return v

def RES(*p):
    def _(v):
        N = v.shape[0]
        tup = (N,) + p
        #print (v.shape)
        return F.reshape(v,tup)
    return _

def Add(v1):
    def _(v2):
        return v1 + v2
    return _

class PRD(Chain):
    def __init__(this):
        super().__init__(
            p1 = L.Linear(2,32),
            p2 = L.Linear(32,64),
            p3 = L.Linear(64,64),
            p4 = L.Linear(64,64),
            p5 = L.Linear(64,64),
            r1 = L.Linear(64,1),
            q1 = L.Linear(1,2),
        )
    def __call__(this,x,test = False):
        ac = F.absolute
        h = Path(x)(this.p1)(ac)(this.p2)(ac)(this.p3)(ac)(this.p4)(ac)(this.p5)(ac)(this.r1)(ac)()
        q = h
        h = Path(h)(this.q1)()
        if test:
            return (h,q)
        else:
            return h
    
prd = PRD()
mdl = L.Classifier(prd)
xp.model_init(mdl)

opt = optimizers.Adam()
opt.setup(prd)
opt.add_hook(chainer.optimizer.WeightDecay(0.0001))

# %%
stp = 10000
prt = 500

for i in range(stp):
    x,t = getMini(dx,dt,50)

    loss = mdl(x,t)
    
    prd.cleargrads()
    loss.backward()
    opt.update()
    
    if i % prt == 0:
        print (i,loss.data)
# Out:
# 0 1.1124027967453003
# 500 0.7134865522384644
# 1000 0.6405144333839417
# 1500 0.6193901300430298
# 2000 0.6104946732521057
# 2500 0.6147761940956116
# 3000 0.4430834949016571
# 3500 0.5194987654685974
# 4000 0.36480608582496643
# 4500 0.4025835394859314
# 5000 0.3199161887168884
# 5500 0.30989596247673035
# 6000 0.23929816484451294
# 6500 0.17794093489646912
# 7000 0.3482343554496765
# 7500 0.1016940027475357
# 8000 0.3233370780944824
# 8500 0.1688757687807083
# 9000 0.40714141726493835
# 9500 0.30556145310401917

# %%
(ex,et) = mk_seq_dat(50000,True)

ey,q = prd(ex*2,True)

_dx = cuda.to_cpu(ex)
_dy = cuda.to_cpu(ey.data)
_dy = np.argmax(_dy,axis=1)
_q  = cuda.to_cpu(q.data).reshape(-1)

yy = 3

#plt.scatter(_dx[:,0][_dy==0],_dx[:,1][_dy==0],c=_q[_dy==0]*yy)
#plt.scatter(_dx[:,0][_dy==1],_dx[:,1][_dy==1],c=_q[_dy==1]*yy)

plt.scatter(_dx[:,0],_dx[:,1],c=_q*2,s=8)
